# %%
# !pip install arxiv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting arxiv
#   Using cached arxiv-2.3.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting feedparser~=6.0.10 (from arxiv)
#   Using cached feedparser-6.0.12-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: requests~=2.32.0 in c:\users\saura\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from arxiv) (2.32.5)
# Collecting sgmllib3k (from feedparser~=6.0.10->arxiv)
#   Using cached sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\saura\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests~=2.32.0->arxiv) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\saura\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests~=2.32.0->arxiv) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\saura\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests~=2.32.0->arxiv) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\saura\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests~=2.32.0->arxiv) (2025.10.5)
# Downloading arxiv-2.3.0-py3-none-any.whl (11 kB)
# Downloading feedparser-6.0.12-py3-none-any.whl (81 kB)
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (pyproject.toml): started
#   Building wheel for sgmllib3k (pyproject.toml): finished with status 'done'
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6105 sha256=45b2b8e3c18ca68227724a85fa8fa036fb548e861fd9fe14cbceb8cfc5d0ee13
#   Stored in directory: c:\users\saura\appdata\local\pip\cache\wheels\3d\4d\ef\37cdccc18d6fd7e0dd7817dcdf9146d4d6789c32a227a28134
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser, arxiv
#
#    ------------- -------------------------- 1/3 [feedparser]
#    ------------- -------------------------- 1/3 [feedparser]
#    ------------- -------------------------- 1/3 [feedparser]
#    ------------- -------------------------- 1/3 [feedparser]
#    ------------- -------------------------- 1/3 [feedparser]
#    ---------------------------------------- 3/3 [arxiv]
#
# Successfully installed arxiv-2.3.0 feedparser-6.0.12 sgmllib3k-1.0.0

# %%
# !pip install wikipedia
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting wikipedia
#   Using cached wikipedia-1.4.0.tar.gz (27 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: beautifulsoup4 in c:\users\saura\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from wikipedia) (4.14.2)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\saura\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from wikipedia) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\saura\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\saura\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\saura\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\saura\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2025.10.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\saura\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from beautifulsoup4->wikipedia) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\saura\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from beautifulsoup4->wikipedia) (4.15.0)
# Building wheels for collected packages: wikipedia
#   Building wheel for wikipedia (pyproject.toml): started
#   Building wheel for wikipedia (pyproject.toml): finished with status 'done'
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11785 sha256=f166f1bd8bfcef8a4d69ecd59c86580ceea80651416693995c96f4659184d125
#   Stored in directory: c:\users\saura\appdata\local\pip\cache\wheels\79\1d\c8\b64e19423cc5a2a339450ea5d145e7c8eb3d4aa2b150cde33b
# Successfully built wikipedia
# Installing collected packages: wikipedia
# Successfully installed wikipedia-1.4.0

# %%
from langchain_community.tools import WikipediaQueryRun 
from langchain_community.utilities import WikipediaAPIWrapper

# %%
WikipediaAPI = WikipediaAPIWrapper(top_k_results=1, doc_content_chars_max= 200)
tool= WikipediaQueryRun(api_wrappeer=WikipediaAPI)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[4], line 2
#       1 WikipediaAPI = WikipediaAPIWrapper(top_k_results=1, doc_content_chars_max= 200)
# ----> 2 tool= WikipediaQueryRun(api_wrappeer=WikipediaAPI)
#
# File c:\Users\saura\Downloads\Gaurav Files\LangChain\Project1\.venv\Lib\site-packages\langchain_core\tools\base.py:515, in BaseTool.__init__(self, **kwargs)
#     510     msg = (
#     511         "args_schema must be a subclass of pydantic BaseModel or "
#     512         f"a JSON schema dict. Got: {kwargs['args_schema']}."
#     513     )
#     514     raise TypeError(msg)
# --> 515 super().__init__(**kwargs)
#
# File c:\Users\saura\Downloads\Gaurav Files\LangChain\Project1\.venv\Lib\site-packages\langchain_core\load\serializable.py:116, in Serializable.__init__(self, *args, **kwargs)
#     114 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     115     """"""  # noqa: D419  # Intentional blank docstring
# --> 116     super().__init__(*args, **kwargs)
#
# File c:\Users\saura\Downloads\Gaurav Files\LangChain\Project1\.venv\Lib\site-packages\pydantic\main.py:250, in BaseModel.__init__(self, **data)
#     248 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     249 __tracebackhide__ = True
# --> 250 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     251 if self is not validated_self:
#     252     warnings.warn(
#     253         'A custom validator is returning a value other than `self`.\n'
#     254         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     255         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     256         stacklevel=2,
#     257     )
#
# ValidationError: 1 validation error for WikipediaQueryRun
# api_wrapper
#   Field required [type=missing, input_value={'api_wrappeer': Wikipedi..._content_chars_max=200)}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
